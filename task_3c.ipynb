# %%
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-20, 20, 0.5)
y1 = 2/x
plt.plot(x, y1)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide
