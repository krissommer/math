# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(-2*np.pi, 3*np.pi, 201)
plt.plot(x, 0.5 * np.cos(x - 1) + 1)
plt.plot(x, np.cos(x))
plt.plot(x, 0.5 * np.cos(x - 2) - 0.5)
plt.xlabel('x')
plt.xlabel('y')
plt.grid(True)
plt.show()
