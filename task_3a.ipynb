# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 1000)
r = 5
y = np.sqrt(r**2-x**2)
y1 = -np.sqrt(r**2-x**2)
plt.plot(x, y, "m-")
plt.plot(x, y1, "m-")
plt.axis('equal')
plt.show()
