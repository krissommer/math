# %%
import numpy as np
import itertools

# %%
for p in itertools.product("0123", repeat=2):
    print(''.join(p))
# Out:
# 00
# 01
# 02
# 03
# 10
# 11
# 12
# 13
# 20
# 21
# 22
# 23
# 30
# 31
# 32
# 33
